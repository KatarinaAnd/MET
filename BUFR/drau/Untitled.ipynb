# %%
import json
from unittest.mock import NonCallableMock
import pandas as pd
import xarray as xr
import yaml
import time
from itertools import dropwhile
import sys 
import os
import subprocess
from eccodes import *
import requests
import argparse
from io import StringIO
import logging
from logging.handlers import TimedRotatingFileHandler
import matplotlib.pyplot as plt
import numpy as np
import traceback
from SPARQLWrapper import SPARQLWrapper, JSON
import operator
import re
from dateutil.relativedelta import relativedelta
sys.path.append('/home/katarinana/work_desk/BUFR/funcs')
from get_keywords import get_keywords
from code_tables import *
from useful_functions import *
import netCDF4
import glob
from datetime import datetime, timedelta, date
from calendar import monthrange, month_name
from feilfil import langvariabel

# %%
lang = langvariabel()

# %%
json.loads(lang)
# Out:
# {'messages': [{'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 4802669,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'longStationName',
#    'value': 'UW-TC-1W-0018',
#    'index': 2,
#    'code': '001019',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 256},
#   {'key': 'dataBuoyType',
#    'value': 0,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'timeSignificance',
#    'value': 26,
#    'index': 4,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 5,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 6,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 7,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 8,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 9,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 76.8714,
#    'index': 10,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -175.014,
#    'index': 11,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'platformTransmitterIdNumber',
#    'value': '300534062895730',
#    'index': 12,
#    'code': '001051',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 128},
#   {'key': 'dataCollectionLocationSystem',
#    'value': 8,
#    'index': 13,
#    'code': '002148',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'directionOfMotionOfMovingObservingPlatform',
#    'value': None,
#    'index': 14,
#    'code': '001012',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'platformDriftSpeed',
#    'value': None,
#    'index': 15,
#    'code': '001014',
#    'units': 'm/s',
#    'scale': 2,
#    'reference': 0,
#    'width': 10},
#   {'key': 'qualityOfBuoySatelliteTransmission',
#    'value': 0,
#    'index': 16,
#    'code': '033022',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'qualityOfBuoyLocation',
#    'value': 0,
#    'index': 17,
#    'code': '033023',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'locationQualityClassRangeOfRadiusOf66Confidence',
#    'value': None,
#    'index': 18,
#    'code': '033027',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'batteryVoltageLargeRange',
#    'value': 11.2,
#    'index': 19,
#    'code': '025026',
#    'units': 'V',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'drogueType',
#    'value': 1,
#    'index': 20,
#    'code': '002034',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'lagrangianDrifterDrogueStatus',
#    'value': None,
#    'index': 21,
#    'code': '022060',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'drogueDepth',
#    'value': None,
#    'index': 22,
#    'code': '007070',
#    'units': 'm',
#    'scale': 0,
#    'reference': 0,
#    'width': 10},
#   {'key': 'lagrangianDrifterSubmergenceTimeSubmerged',
#    'value': 0,
#    'index': 23,
#    'code': '002190',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'timeSignificance',
#    'value': 25,
#    'index': 24,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 25,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 26,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 27,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 28,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 29,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.1,
#    'index': 30,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 31,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': None,
#    'index': 32,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'seaSurfaceSalinity',
#    'value': None,
#    'index': 33,
#    'code': '022059',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'surfaceType',
#    'value': 0,
#    'index': 34,
#    'code': '008029',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'iceThickness',
#    'value': None,
#    'index': 35,
#    'code': '013115',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 19},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.05,
#    'index': 37,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'indicatorForDigitization',
#    'value': 0,
#    'index': 38,
#    'code': '002032',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': 0,
#    'index': 39,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'delayedDescriptorReplicationFactor',
#    'value': 11,
#    'index': 40,
#    'code': '031001',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'depthBelowWaterSurface',
#    'value': 5,
#    'index': 41,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 264.6,
#    'index': 42,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 43,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 7.5,
#    'index': 44,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 45,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 46,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 10,
#    'index': 47,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 48,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 49,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 15,
#    'index': 50,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 265.22,
#    'index': 51,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 52,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 20,
#    'index': 53,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 266.93,
#    'index': 54,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 55,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 25,
#    'index': 56,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 264.45,
#    'index': 57,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 58,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 30,
#    'index': 59,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 263.59,
#    'index': 60,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 61,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 35,
#    'index': 62,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 63,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 64,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 40,
#    'index': 65,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 266.03,
#    'index': 66,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 67,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 50,
#    'index': 68,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.51,
#    'index': 69,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 70,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': 60,
#    'index': 71,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.52,
#    'index': 72,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 73,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'temperatureObservationPrecision',
#    'value': None,
#    'index': 74,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'nonCoordinatePressure',
#    'value': None,
#    'index': 75,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': 104000,
#    'index': 76,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 77,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 78,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 79,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 4802637,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'longStationName',
#    'value': 'UW-SVPS-XIM-0003',
#    'index': 2,
#    'code': '001019',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 256},
#   {'key': 'dataBuoyType',
#    'value': 0,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'timeSignificance',
#    'value': 26,
#    'index': 4,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 5,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 6,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 7,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 8,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 9,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 77.8675,
#    'index': 10,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -174.518,
#    'index': 11,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'platformTransmitterIdNumber',
#    'value': '300534062894740',
#    'index': 12,
#    'code': '001051',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 128},
#   {'key': 'dataCollectionLocationSystem',
#    'value': 8,
#    'index': 13,
#    'code': '002148',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'directionOfMotionOfMovingObservingPlatform',
#    'value': None,
#    'index': 14,
#    'code': '001012',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'platformDriftSpeed',
#    'value': None,
#    'index': 15,
#    'code': '001014',
#    'units': 'm/s',
#    'scale': 2,
#    'reference': 0,
#    'width': 10},
#   {'key': 'qualityOfBuoySatelliteTransmission',
#    'value': 0,
#    'index': 16,
#    'code': '033022',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'qualityOfBuoyLocation',
#    'value': 0,
#    'index': 17,
#    'code': '033023',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'locationQualityClassRangeOfRadiusOf66Confidence',
#    'value': None,
#    'index': 18,
#    'code': '033027',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'batteryVoltageLargeRange',
#    'value': 10.6,
#    'index': 19,
#    'code': '025026',
#    'units': 'V',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'drogueType',
#    'value': 1,
#    'index': 20,
#    'code': '002034',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'lagrangianDrifterDrogueStatus',
#    'value': None,
#    'index': 21,
#    'code': '022060',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'drogueDepth',
#    'value': None,
#    'index': 22,
#    'code': '007070',
#    'units': 'm',
#    'scale': 0,
#    'reference': 0,
#    'width': 10},
#   {'key': 'lagrangianDrifterSubmergenceTimeSubmerged',
#    'value': 0,
#    'index': 23,
#    'code': '002190',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'timeSignificance',
#    'value': 25,
#    'index': 24,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 25,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 26,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 27,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 28,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 29,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.1,
#    'index': 30,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 31,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': None,
#    'index': 32,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'seaSurfaceSalinity',
#    'value': None,
#    'index': 33,
#    'code': '022059',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'surfaceType',
#    'value': 0,
#    'index': 34,
#    'code': '008029',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'iceThickness',
#    'value': None,
#    'index': 35,
#    'code': '013115',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 19},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.05,
#    'index': 37,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'indicatorForDigitization',
#    'value': 0,
#    'index': 38,
#    'code': '002032',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': 0,
#    'index': 39,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'delayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 40,
#    'code': '031001',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'depthBelowWaterSurface',
#    'value': 5,
#    'index': 41,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 310.58,
#    'index': 42,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 43,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'temperatureObservationPrecision',
#    'value': None,
#    'index': 44,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'nonCoordinatePressure',
#    'value': None,
#    'index': 45,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': None,
#    'index': 46,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 47,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 48,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 49,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 4802667,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'longStationName',
#    'value': 'UW-TCS-37IM-S9XT-0001',
#    'index': 2,
#    'code': '001019',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 256},
#   {'key': 'dataBuoyType',
#    'value': 0,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'timeSignificance',
#    'value': 26,
#    'index': 4,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 5,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 6,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 7,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 8,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 9,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 77.3563,
#    'index': 10,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -178.182,
#    'index': 11,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'platformTransmitterIdNumber',
#    'value': '300534062896730',
#    'index': 12,
#    'code': '001051',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 128},
#   {'key': 'dataCollectionLocationSystem',
#    'value': 8,
#    'index': 13,
#    'code': '002148',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'directionOfMotionOfMovingObservingPlatform',
#    'value': None,
#    'index': 14,
#    'code': '001012',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'platformDriftSpeed',
#    'value': None,
#    'index': 15,
#    'code': '001014',
#    'units': 'm/s',
#    'scale': 2,
#    'reference': 0,
#    'width': 10},
#   {'key': 'qualityOfBuoySatelliteTransmission',
#    'value': 0,
#    'index': 16,
#    'code': '033022',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'qualityOfBuoyLocation',
#    'value': 0,
#    'index': 17,
#    'code': '033023',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'locationQualityClassRangeOfRadiusOf66Confidence',
#    'value': None,
#    'index': 18,
#    'code': '033027',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'batteryVoltageLargeRange',
#    'value': 10.8,
#    'index': 19,
#    'code': '025026',
#    'units': 'V',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'drogueType',
#    'value': 1,
#    'index': 20,
#    'code': '002034',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'lagrangianDrifterDrogueStatus',
#    'value': None,
#    'index': 21,
#    'code': '022060',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'drogueDepth',
#    'value': None,
#    'index': 22,
#    'code': '007070',
#    'units': 'm',
#    'scale': 0,
#    'reference': 0,
#    'width': 10},
#   {'key': 'lagrangianDrifterSubmergenceTimeSubmerged',
#    'value': 0,
#    'index': 23,
#    'code': '002190',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'timeSignificance',
#    'value': 25,
#    'index': 24,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 25,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 26,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 27,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 28,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 29,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.1,
#    'index': 30,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 31,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': None,
#    'index': 32,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'seaSurfaceSalinity',
#    'value': None,
#    'index': 33,
#    'code': '022059',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'surfaceType',
#    'value': 0,
#    'index': 34,
#    'code': '008029',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'iceThickness',
#    'value': None,
#    'index': 35,
#    'code': '013115',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 19},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.05,
#    'index': 37,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'indicatorForDigitization',
#    'value': 0,
#    'index': 38,
#    'code': '002032',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': 0,
#    'index': 39,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'delayedDescriptorReplicationFactor',
#    'value': 5,
#    'index': 40,
#    'code': '031001',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 41,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.48,
#    'index': 42,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 43,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 44,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.48,
#    'index': 45,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 46,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 47,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.48,
#    'index': 48,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 49,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 50,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.48,
#    'index': 51,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 52,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 53,
#    'code': '007062',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 17},
#   {'key': 'oceanographicWaterTemperature',
#    'value': 271.54,
#    'index': 54,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'salinity',
#    'value': None,
#    'index': 55,
#    'code': '022062',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'temperatureObservationPrecision',
#    'value': None,
#    'index': 56,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'nonCoordinatePressure',
#    'value': None,
#    'index': 57,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': None,
#    'index': 58,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 59,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 60,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 61,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 4802634,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'longStationName',
#    'value': 'UW-IB-SVPS-0004',
#    'index': 2,
#    'code': '001019',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 256},
#   {'key': 'dataBuoyType',
#    'value': 0,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'timeSignificance',
#    'value': 26,
#    'index': 4,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 5,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 6,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 7,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 8,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 9,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 79.1599,
#    'index': 10,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -164.946,
#    'index': 11,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'platformTransmitterIdNumber',
#    'value': '300534062897730',
#    'index': 12,
#    'code': '001051',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 128},
#   {'key': 'dataCollectionLocationSystem',
#    'value': 8,
#    'index': 13,
#    'code': '002148',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'directionOfMotionOfMovingObservingPlatform',
#    'value': None,
#    'index': 14,
#    'code': '001012',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'platformDriftSpeed',
#    'value': None,
#    'index': 15,
#    'code': '001014',
#    'units': 'm/s',
#    'scale': 2,
#    'reference': 0,
#    'width': 10},
#   {'key': 'qualityOfBuoySatelliteTransmission',
#    'value': 0,
#    'index': 16,
#    'code': '033022',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'qualityOfBuoyLocation',
#    'value': 0,
#    'index': 17,
#    'code': '033023',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'locationQualityClassRangeOfRadiusOf66Confidence',
#    'value': None,
#    'index': 18,
#    'code': '033027',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'batteryVoltageLargeRange',
#    'value': 11.2,
#    'index': 19,
#    'code': '025026',
#    'units': 'V',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'drogueType',
#    'value': 1,
#    'index': 20,
#    'code': '002034',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'lagrangianDrifterDrogueStatus',
#    'value': None,
#    'index': 21,
#    'code': '022060',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'drogueDepth',
#    'value': None,
#    'index': 22,
#    'code': '007070',
#    'units': 'm',
#    'scale': 0,
#    'reference': 0,
#    'width': 10},
#   {'key': 'lagrangianDrifterSubmergenceTimeSubmerged',
#    'value': 0,
#    'index': 23,
#    'code': '002190',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'timeSignificance',
#    'value': 25,
#    'index': 24,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 25,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 26,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 27,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 28,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 29,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.1,
#    'index': 30,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 31,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': None,
#    'index': 32,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'seaSurfaceSalinity',
#    'value': None,
#    'index': 33,
#    'code': '022059',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'surfaceType',
#    'value': 0,
#    'index': 34,
#    'code': '008029',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'iceThickness',
#    'value': None,
#    'index': 35,
#    'code': '013115',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 19},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'nonCoordinatePressure',
#    'value': None,
#    'index': 37,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': None,
#    'index': 38,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 39,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 40,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 41,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 4802633,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'longStationName',
#    'value': 'UW-IB-SVPS-0003',
#    'index': 2,
#    'code': '001019',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 256},
#   {'key': 'dataBuoyType',
#    'value': 0,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'timeSignificance',
#    'value': 26,
#    'index': 4,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 5,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 6,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 7,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 8,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 9,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 78.1999,
#    'index': 10,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -164.398,
#    'index': 11,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'platformTransmitterIdNumber',
#    'value': '300534062894700',
#    'index': 12,
#    'code': '001051',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 128},
#   {'key': 'dataCollectionLocationSystem',
#    'value': 8,
#    'index': 13,
#    'code': '002148',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'directionOfMotionOfMovingObservingPlatform',
#    'value': None,
#    'index': 14,
#    'code': '001012',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'platformDriftSpeed',
#    'value': None,
#    'index': 15,
#    'code': '001014',
#    'units': 'm/s',
#    'scale': 2,
#    'reference': 0,
#    'width': 10},
#   {'key': 'qualityOfBuoySatelliteTransmission',
#    'value': 0,
#    'index': 16,
#    'code': '033022',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'qualityOfBuoyLocation',
#    'value': 0,
#    'index': 17,
#    'code': '033023',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'locationQualityClassRangeOfRadiusOf66Confidence',
#    'value': None,
#    'index': 18,
#    'code': '033027',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'batteryVoltageLargeRange',
#    'value': 11.2,
#    'index': 19,
#    'code': '025026',
#    'units': 'V',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'drogueType',
#    'value': 1,
#    'index': 20,
#    'code': '002034',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'lagrangianDrifterDrogueStatus',
#    'value': None,
#    'index': 21,
#    'code': '022060',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'drogueDepth',
#    'value': None,
#    'index': 22,
#    'code': '007070',
#    'units': 'm',
#    'scale': 0,
#    'reference': 0,
#    'width': 10},
#   {'key': 'lagrangianDrifterSubmergenceTimeSubmerged',
#    'value': 0,
#    'index': 23,
#    'code': '002190',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'timeSignificance',
#    'value': 25,
#    'index': 24,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 25,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 26,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 27,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 28,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 29,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'temperatureObservationPrecision',
#    'value': 0.1,
#    'index': 30,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'oceanographicWaterTemperature',
#    'value': None,
#    'index': 31,
#    'code': '022043',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'methodOfSalinityOrDepthMeasurement',
#    'value': None,
#    'index': 32,
#    'code': '002033',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'seaSurfaceSalinity',
#    'value': None,
#    'index': 33,
#    'code': '022059',
#    'units': '0/00',
#    'scale': 2,
#    'reference': 0,
#    'width': 14},
#   {'key': 'surfaceType',
#    'value': 0,
#    'index': 34,
#    'code': '008029',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'iceThickness',
#    'value': None,
#    'index': 35,
#    'code': '013115',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 19},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'nonCoordinatePressure',
#    'value': None,
#    'index': 37,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': None,
#    'index': 38,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 39,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 40,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 41,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 4802639,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'longStationName',
#    'value': 'UW-SVPS2-37IM-0002',
#    'index': 2,
#    'code': '001019',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 256},
#   {'key': 'dataBuoyType',
#    'value': 0,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'timeSignificance',
#    'value': 26,
#    'index': 4,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 5,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 6,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 7,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 8,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 31,
#    'index': 9,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 73.9849,
#    'index': 10,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -179.539,
#    'index': 11,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'platformTransmitterIdNumber',
#    'value': '300534063807110',
#    'index': 12,
#    'code': '001051',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 128},
#   {'key': 'dataCollectionLocationSystem',
#    'value': 8,
#    'index': 13,
#    'code': '002148',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'directionOfMotionOfMovingObservingPlatform',
#    'value': None,
#    'index': 14,
#    'code': '001012',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'platformDriftSpeed',
#    'value': None,
#    'index': 15,
#    'code': '001014',
#    'units': 'm/s',
#    'scale': 2,
#    'reference': 0,
#    'width': 10},
#   {'key': 'qualityOfBuoySatelliteTransmission',
#    'value': 0,
#    'index': 16,
#    'code': '033022',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'qualityOfBuoyLocation',
#    'value': 0,
#    'index': 17,
#    'code': '033023',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 2},
#   {'key': 'locationQualityClassRangeOfRadiusOf66Confidence',
#    'value': None,
#    'index': 18,
#    'code': '033027',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'batteryVoltageLargeRange',
#    'value': 13,
#    'index': 19,
#    'code': '025026',
#    'units': 'V',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'drogueType',
#    'value': 1,
#    'index': 20,
#    'code': '002034',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'lagrangianDrifterDrogueStatus',
#    'value': None,
#    'index': 21,
#    'code': '022060',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 3},
#   {'key': 'drogueDepth',
#    'value': None,
#    'index': 22,
#    'code': '007070',
#    'units': 'm',
#    'scale': 0,
#    'reference': 0,
#    'width': 10},
#   {'key': 'lagrangianDrifterSubmergenceTimeSubmerged',
#    'value': 0,
#    'index': 23,
#    'code': '002190',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'timeSignificance',
#    'value': 25,
#    'index': 24,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'year',
#    'value': 2023,
#    'index': 25,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 26,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 27,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
# ...
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 7,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 8,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 23.5283,
#    'index': 9,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -153.792,
#    'index': 10,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'nonCoordinatePressure',
#    'value': 101610,
#    'index': 11,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': 101640,
#    'index': 12,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'heightOfSensorAboveWaterSurface',
#    'value': None,
#    'index': 13,
#    'code': '007033',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'airTemperature',
#    'value': 297.05,
#    'index': 14,
#    'code': '012101',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 16},
#   {'key': 'dewpointTemperature',
#    'value': 293.75,
#    'index': 15,
#    'code': '012103',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 16},
#   {'key': 'relativeHumidity',
#    'value': None,
#    'index': 16,
#    'code': '013003',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'heightOfSensorAboveWaterSurface',
#    'value': 3.7,
#    'index': 17,
#    'code': '007033',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'timeSignificance',
#    'value': None,
#    'index': 18,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 19,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'windDirection',
#    'value': 119,
#    'index': 20,
#    'code': '011001',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'windSpeed',
#    'value': 5.5,
#    'index': 21,
#    'code': '011002',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'timeSignificance',
#    'value': None,
#    'index': 22,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 23,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'maximumWindGustSpeed',
#    'value': 10.1,
#    'index': 24,
#    'code': '011041',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 25,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'heightOfSensorAboveWaterSurface',
#    'value': None,
#    'index': 26,
#    'code': '007033',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'temperatureObservationPrecision',
#    'value': None,
#    'index': 27,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 28,
#    'code': '007063',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 20},
#   {'key': 'seaSurfaceTemperature',
#    'value': 297.45,
#    'index': 29,
#    'code': '022049',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 30,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 31,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 32,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 33,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 34,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 35,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 37,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 38,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': None,
#    'index': 39,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'timePeriod',
#    'value': -7,
#    'index': 40,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'windDirection',
#    'value': None,
#    'index': 41,
#    'code': '011001',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'windSpeed',
#    'value': 6,
#    'index': 42,
#    'code': '011002',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 43,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'timePeriod',
#    'value': -10,
#    'index': 44,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'maximumWindGustDirection',
#    'value': None,
#    'index': 45,
#    'code': '011043',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'maximumWindGustSpeed',
#    'value': None,
#    'index': 46,
#    'code': '011041',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'delayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 47,
#    'code': '031001',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 5100003,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'stationOrSiteName',
#    'value': 'WESTERN HAWAII',
#    'index': 2,
#    'code': '001015',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 160},
#   {'key': 'dataBuoyType',
#    'value': 16,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'year',
#    'value': 2023,
#    'index': 4,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 5,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 6,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 7,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 8,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 19.1961,
#    'index': 9,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -160.639,
#    'index': 10,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'nonCoordinatePressure',
#    'value': 101470,
#    'index': 11,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': 101500,
#    'index': 12,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'heightOfSensorAboveWaterSurface',
#    'value': None,
#    'index': 13,
#    'code': '007033',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'airTemperature',
#    'value': 297.95,
#    'index': 14,
#    'code': '012101',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 16},
#   {'key': 'dewpointTemperature',
#    'value': 293.95,
#    'index': 15,
#    'code': '012103',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 16},
#   {'key': 'relativeHumidity',
#    'value': None,
#    'index': 16,
#    'code': '013003',
#    'units': '%',
#    'scale': 0,
#    'reference': 0,
#    'width': 7},
#   {'key': 'heightOfSensorAboveWaterSurface',
#    'value': 3.8,
#    'index': 17,
#    'code': '007033',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'timeSignificance',
#    'value': None,
#    'index': 18,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 19,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'windDirection',
#    'value': 83,
#    'index': 20,
#    'code': '011001',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'windSpeed',
#    'value': 5.9,
#    'index': 21,
#    'code': '011002',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'timeSignificance',
#    'value': None,
#    'index': 22,
#    'code': '008021',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 23,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'maximumWindGustSpeed',
#    'value': 8.5,
#    'index': 24,
#    'code': '011041',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 25,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'heightOfSensorAboveWaterSurface',
#    'value': None,
#    'index': 26,
#    'code': '007033',
#    'units': 'm',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'temperatureObservationPrecision',
#    'value': None,
#    'index': 27,
#    'code': '002005',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 7},
#   {'key': 'depthBelowWaterSurface',
#    'value': None,
#    'index': 28,
#    'code': '007063',
#    'units': 'm',
#    'scale': 2,
#    'reference': 0,
#    'width': 20},
#   {'key': 'seaSurfaceTemperature',
#    'value': None,
#    'index': 29,
#    'code': '022049',
#    'units': 'K',
#    'scale': 2,
#    'reference': 0,
#    'width': 15},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 30,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 31,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 32,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 33,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 34,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 35,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 36,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 37,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'timePeriod',
#    'value': None,
#    'index': 38,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'pressureReducedToMeanSeaLevel',
#    'value': None,
#    'index': 39,
#    'code': '010051',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   {'key': 'timePeriod',
#    'value': -4,
#    'index': 40,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'windDirection',
#    'value': None,
#    'index': 41,
#    'code': '011001',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'windSpeed',
#    'value': 6.5,
#    'index': 42,
#    'code': '011002',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'shortDelayedDescriptorReplicationFactor',
#    'value': 1,
#    'index': 43,
#    'code': '031000',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 1},
#   {'key': 'timePeriod',
#    'value': -5,
#    'index': 44,
#    'code': '004025',
#    'units': 'min',
#    'scale': 0,
#    'reference': -2048,
#    'width': 12},
#   {'key': 'maximumWindGustDirection',
#    'value': None,
#    'index': 45,
#    'code': '011043',
#    'units': 'deg',
#    'scale': 0,
#    'reference': 0,
#    'width': 9},
#   {'key': 'maximumWindGustSpeed',
#    'value': None,
#    'index': 46,
#    'code': '011041',
#    'units': 'm/s',
#    'scale': 1,
#    'reference': 0,
#    'width': 12},
#   {'key': 'delayedDescriptorReplicationFactor',
#    'value': 0,
#    'index': 47,
#    'code': '031001',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 8},
#   {'key': 'subsetNumber', 'value': 1},
#   {'key': 'marineObservingPlatformIdentifier',
#    'value': 5100002,
#    'index': 1,
#    'code': '001087',
#    'units': 'Numeric',
#    'scale': 0,
#    'reference': 0,
#    'width': 23},
#   {'key': 'stationOrSiteName',
#    'value': 'SOUTHWESTERN HAWAII',
#    'index': 2,
#    'code': '001015',
#    'units': 'CCITT IA5',
#    'scale': 0,
#    'reference': 0,
#    'width': 160},
#   {'key': 'dataBuoyType',
#    'value': 16,
#    'index': 3,
#    'code': '002149',
#    'units': 'CODE TABLE',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'year',
#    'value': 2023,
#    'index': 4,
#    'code': '004001',
#    'units': 'a',
#    'scale': 0,
#    'reference': 0,
#    'width': 12},
#   {'key': 'month',
#    'value': 1,
#    'index': 5,
#    'code': '004002',
#    'units': 'mon',
#    'scale': 0,
#    'reference': 0,
#    'width': 4},
#   {'key': 'day',
#    'value': 22,
#    'index': 6,
#    'code': '004003',
#    'units': 'd',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'hour',
#    'value': 23,
#    'index': 7,
#    'code': '004004',
#    'units': 'h',
#    'scale': 0,
#    'reference': 0,
#    'width': 5},
#   {'key': 'minute',
#    'value': 30,
#    'index': 8,
#    'code': '004005',
#    'units': 'min',
#    'scale': 0,
#    'reference': 0,
#    'width': 6},
#   {'key': 'latitude',
#    'value': 17.0422,
#    'index': 9,
#    'code': '005001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -9000000,
#    'width': 25},
#   {'key': 'longitude',
#    'value': -157.746,
#    'index': 10,
#    'code': '006001',
#    'units': 'deg',
#    'scale': 5,
#    'reference': -18000000,
#    'width': 26},
#   {'key': 'nonCoordinatePressure',
#    'value': 101320,
#    'index': 11,
#    'code': '010004',
#    'units': 'Pa',
#    'scale': -1,
#    'reference': 0,
#    'width': 14},
#   ...]}
